# %%
from bs4 import BeautifulSoup
import urllib.request as ur

#loop through the 7 pages of undergraduate courses
for i in range (0,6):

    #read and open url to scrape
    urlToScrape = "https://www.city.ac.uk/courses?level=Undergraduate&p=" + str(i * 10 + 1)
    r = ur.urlopen(urlToScrape).read()
    soup = BeautifulSoup(r, "lxml")

    #attributes for each course
    courseList = soup.find_all('div', attrs={'class': 'course-finder__results__item course-finder__results__item--undergraduate'})

    #loop through each course
    for courseListItem in courseList:
        
        #get course name
        try:
            courseNameElement = courseListItem.find('div', attrs={'class': "col-sm-24 col-md-18 col-lg-20"})
            courseName = courseNameElement.find('a').text
        except Exception as e:
            courseName = ''
            #get degree name
        try:
            degreeTypeElement = courseListItem.find('div', attrs={'class': "course-finder__results__item__award"})
            degreeName = degreeTypeElement.text
        except Exception as e:
            degreeName = ''
        
        #get school the course is part of
        try:
            courseSchoolElement = courseListItem.find('div', attrs={'class': "course-finder__results__item__md course-finder__results__item__md--school"})
            courseSchool = courseSchoolElement.find('a').text
        except Exception as e:
            courseSchool = ''
            
        #get course duration    
        try:
            courseDurationElement = courseListItem.find('div', attrs={'class': "course-finder__results__item__md course-finder__results__item__md--duration"})
            courseDuration = courseDurationElement.find_all('span')[2].text
        except Exception as e:
            courseDuration = ''
        
        #get course code
        try:
            courseCodeElement = courseListItem.find('div', attrs={'class': "course-finder__results__item__md course-finder__results__item__md--code"})
            courseCode = courseCodeElement.find_all('span')[2].text
        except Exception as e:
            courseCode = ''
        
        print(courseName)
        print(degreeName)
        print(courseSchool)
        print(courseDuration)
        print(courseCode)
        print ("-------------\n")
# Out:
# Accounting and Finance
# BSc (Hons)
# Cass Business School
# 3 years
# NN43 / N4N3 with placement
# -------------
#
# Actuarial Science
# BSc (Hons)
# Cass Business School
# 3 years
# G322 / G321 with professional placement
# -------------
#
# Adult Nursing
# BSc (Hons)
# School of Health Sciences
# Full-time: three years
# B701
# -------------
#
# Aeronautical Engineering
# BEng (Hons)
# School of Mathematics, Computer Science and Engineering
# 3 years
# H410
# -------------
#
# Aeronautical Engineering
# MEng (Hons)
# School of Mathematics, Computer Science and Engineering
# 4 years or 5 years including a&nbsp;professional placement.
# H403 MEng (Hons), H405 MEng (Hons) with professional placement.
# -------------
#
# Banking and International Finance
# BSc (Hons)
# Cass Business School
# 3 years
# N302 / N312 with placement
# -------------
#
# Biomedical Engineering
# MEng (Hons)
# School of Mathematics, Computer Science and Engineering
# 4 years or 5 years including a professional placement
# BH82; BH11 with professional placement
# -------------
#
# Biomedical Engineering
# BEng (Hons)
# School of Mathematics, Computer Science and Engineering
# 3 years
# BH81
# -------------
#
# Business Management
# BSc (Hons)
# Cass Business School
# 3 years
# N102 / N121 with professional placement
# -------------
#
# Business Management, Digital Innovation and Entrepreneurship
# BSc (Hons)
# Cass Business School
# 3 years
# N103 / N113 with professional placement
# -------------
#
# Business with Finance
# BSc (Hons)
# Cass Business School
# 3 years
# N1N3 / N131 with professional placement
# -------------
#
# Business with Marketing
# BSc (Hons)
# Cass Business School
# 3 years
# N1N5 / N151 with professional placement
# -------------
#
# Child Nursing
# BSc (Hons)
# School of Health Sciences
# Full-time: three years
# B703
# -------------
#
# Civil Engineering
# BEng (Hons)
# School of Mathematics, Computer Science and Engineering
# 3 years
# H200
# -------------
#
# Civil Engineering
# MEng (Hons)
# School of Mathematics, Computer Science and Engineering
# 4 years or 5 years including a professional placement
# H204; H205 with professional placement
# -------------
#
# Computer Science
# MSci (Hons)
# School of Mathematics, Computer Science and Engineering
# 4 years, or 5 years with an industrial placement.
# G401
# -------------
#
# Computer Science
# BSc (Hons)
# School of Mathematics, Computer Science and Engineering
# 3 years or 4 years with a 1 year placement, or the Professional Pathway Scheme (combining the degree with 3 years of IT work experience)
# G400
# -------------
#
# Computer Science with Cyber Security
# MSci (Hons)
# School of Mathematics, Computer Science and Engineering
# 4 years, or 5 years with an industrial placement.
# G4G0
# -------------
#
# Computer Science with Games Technology
# MSci (Hons)
# School of Mathematics, Computer Science and Engineering
# 4 years, or 5 years with an industrial placement
# GG49
# -------------
#
# Computer Science with Games Technology
# BSc (Hons)
# School of Mathematics, Computer Science and Engineering
# 3 years, or 4 years with an industrial placement
# G490
# -------------
#
# Criminology
# BSc (Hons)
# School of Arts and Social Sciences
# 3 or 4 years with a work placement option or study abroad
# 4T82
# -------------
#
# Criminology and Psychology
# BSc (Hons)
# School of Arts and Social Sciences
# 3 years 4 years with a work placement year or study abroad year, to be undertaken between Part 2 and Part 3 of the course.
# L3C8
# -------------
#
# Criminology and Sociology
# BSc (Hons)
# School of Arts and Social Sciences
# 3 years or 4 years with a work placement option or study abroad.
# L390
# -------------
#
# Data Analytics and Actuarial Science
# BSc (Hons)
# Cass Business School
# 3 years
# G3G1
# -------------
#
# Data Science
# MSci (Hons)
# School of Mathematics, Computer Science and Engineering
# Four years or five years including a professional placement
# G102
# -------------
#
# Economics
# BSc (Hons)
# School of Arts and Social Sciences
# 3 years or 4 years with a work placement option.
# L100
# -------------
#
# Economics with Accounting
# BSc (Hons)
# School of Arts and Social Sciences
# 3 years or 4 years with a work placement option.
# LN14
# -------------
#
# Electrical and Electronic Engineering
# BEng (Hons)
# School of Mathematics, Computer Science and Engineering
# 3 years
# H602
# -------------
#
# Electrical and Electronic Engineering
# MEng (Hons)
# School of Mathematics, Computer Science and Engineering
# 4 years or 5 years including a&nbsp;professional placement.
# H607; H609 with a professional placement
# -------------
#
# Engineering
# BEng (Hons)
# School of Mathematics, Computer Science and Engineering
# 3 years
# H101
# -------------
#
# Engineering
# MEng (Hons)
# School of Mathematics, Computer Science and Engineering
# 4 years or 5 years including a professional placement.
# H102; H103 with professional placement
# -------------
#
# English
# BA (Hons)
# School of Arts and Social Sciences
# 3 years, or 4 years with a work placement option or study abroad.
# Q300
# -------------
#
# Finance
# BSc (Hons)
# Cass Business School
# 3 years
# N3N3 / N3N1 with professional placement
# -------------
#
# Finance with Actuarial Science
# BSc (Hons)
# Cass Business School
# 3 years
# G3N3
# -------------
#
# Financial Economics
# BSc (Hons)
# School of Arts and Social Sciences
# 3 years or 4 years with a work placement option.
# L111
# -------------
#
# Health and Social Care
# BSc (Hons)
# School of Health Sciences
# 3 years full-time
# L510
# -------------
#
# History
# BA (Hons)
# School of Arts and Social Sciences
# 3 years, or 4 years with a work placement option or study abroad.
# V100
# -------------
#
# International Business
# BSc (Hons)
# Cass Business School
# 3 years with Term Abroad
# N120: with Term Abroad <br> N111: with Study Abroad year<br> N112:  with Term Abroad & Professional Placement
# -------------
#
# International Political Economy
# BSc (Hons)
# School of Arts and Social Sciences
# 3 years or 4 years with a work placement option.
# 4J80
# -------------
#
# International Politics
# BSc (Hons)
# School of Arts and Social Sciences
# 3 years or 4 years with professional placement.
# L240
# -------------
#
# International Politics and Sociology
# BSc (Hons)
# School of Arts and Social Sciences
# 3 years or 4 years with a work placement option.
# LL23
# -------------
#
# Investment and Financial Risk Management
# BSc (Hons)
# Cass Business School
# 3 years
# N390 / N319 with professional placement
# -------------
#
# Journalism
# BA (Hons)
# School of Arts and Social Sciences
# 3 years or 4 years with a work placement option or study abroad.
# P500
# -------------
#
# Law
# LLB (Hons)
# The City Law School
# 3 years
# M100
# -------------
#
# LLB in Legal Practice (Online)
# LLB (Hons)
# The City Law School
#
#
# -------------
#
# Mathematics
# BSc (Hons)
# School of Mathematics, Computer Science and Engineering
# 3 years or 4 years including a professional placement.
# G100
# -------------
#
# Mathematics and Finance
# BSc (Hons)
# School of Mathematics, Computer Science and Engineering
# 3 years or 4 years including a professional placement.
# GN13
# -------------
#
# Mathematics with Finance and Economics
# BSc (Hons)
# School of Mathematics, Computer Science and Engineering
# 3 years or 4 years including a professional placement.
# G1L1
# -------------
#
# Mechanical Engineering
# BEng (Hons)
# School of Mathematics, Computer Science and Engineering
# Three years
# H300
# -------------
#
# Mechanical Engineering
# MEng (Hons)
# School of Mathematics, Computer Science and Engineering
# Four years or five years including a professional placement.
# H304 MEng (Hons), H305 MEng (Hons) with professional placement
# -------------
#
# Media, Communications and Sociology
# BSc (Hons)
# School of Arts and Social Sciences
# 3 or 4 years with a work placement option or study abroad
# PL33
# -------------
#
# Mental Health Nursing
# BSc (Hons)
# School of Health Sciences
# Full-time: three years
# B702
# -------------
#
# Midwifery
# BSc (Hons)
# School of Health Sciences
# Full-time: 3 years
# B715
# -------------
#
# Music
# BMus (Hons)
# School of Arts and Social Sciences
# 3 years or 4 years with one of the two optional sandwich year routes: a work placement year or study abroad year, to be undertaken between years two and three of the course.
# W300
# -------------
#
# Music, Sound and Technology
# BSc (Hons)
# School of Arts and Social Sciences
# 3 years or 4 years with one of the two optional sandwich year routes: a work placement year or study abroad year, to be undertaken between years two and three of the course.
# W3W7
# -------------
#
# Nursing Studies
# BSc (Hons)
# School of Health Sciences
# Full-time: 2 years Part-time: 3 - 5 years
#
# -------------
#
# Optometry
# BSc (Hons)
# School of Health Sciences
# 3 years (BSc only)
# B510
# -------------
#
# Politics
# BSc (Hons)
# School of Arts and Social Sciences
# 3 years or 4 years with professional placement.
# L200
# -------------
#
# Psychology
# BSc (Hons)
# School of Arts and Social Sciences
# 3 years 4 years with a work placement year or study abroad year, to be undertaken between Part 2 and Part 3 of the course
# C800
# -------------
